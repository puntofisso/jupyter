# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Dataset.csv')

# %%
df.head()
# Out:
#                                 LGD2014 All usual residents  Unnamed: 2  \
# 0                      Northern Ireland           1,810,863         NaN
# 1               Antrim and Newtownabbey             138,567         NaN
# 2                   Ards and North Down             156,672         NaN
# 3  Armagh City, Banbridge and Craigavon             199,693         NaN
# 4                               Belfast             333,871         NaN
#
#   Passports held: No passport Passports held: United Kingdom only  \
# 0                     341,428                           1,035,451
# 1                      21,744                              96,539
# 2                      22,496                             120,061
# 3                      38,671                             113,450
# 4                      53,584                             186,552
#
#   Passports held: Ireland only  \
# 0                      342,887
# 1                       14,018
# 2                        7,758
# 3                       35,740
# 4                       72,428
#
#   Passports held: United Kingdom and Ireland only  \
# 0                                          30,276
# 1                                           2,098
# 2                                           3,031
# 3                                           3,043
# 4                                           6,794
#
#   Passports held: United Kingdom and other (not Ireland)  \
# 0                                              4,291
# 1                                                355
# 2                                                593
# 3                                                406
# 4                                              1,040
#
#   Passports held: Ireland and other (not United Kingdom)  \
# 0                                              2,282
# 1                                                128
# 2                                                118
# 3                                                169
# 4                                                484
#
#   Passports held: EU/EEA (not United Kingdom or Ireland)  \
# 0                                             39,103
# 1                                              2,371
# 2                                              1,448
# 3                                              7,050
# 4                                              7,302
#
#   Passports held: Other  Passports held: No passport (%)  \
# 0                15,145                            18.85
# 1                 1,314                            15.69
# 2                 1,167                            14.36
# 3                 1,164                            19.37
# 4                 5,687                            16.05
#
#    Passports held: United Kingdom only (%)  Passports held: Ireland only (%)  \
# 0                                    57.18                             18.94
# 1                                    69.67                             10.12
# 2                                    76.63                              4.95
# 3                                    56.81                             17.90
# 4                                    55.88                             21.69
#
#    Passports held: United Kingdom and Ireland only (%)  \
# 0                                               1.67
# 1                                               1.51
# 2                                               1.93
# 3                                               1.52
# 4                                               2.03
#
#    Passports held: United Kingdom and other (not Ireland) (%)  \
# 0                                               0.24
# 1                                               0.26
# 2                                               0.38
# 3                                               0.20
# 4                                               0.31
#
#    Passports held: Ireland and other (not United Kingdom) (%)  \
# 0                                               0.13
# 1                                               0.09
# 2                                               0.08
# 3                                               0.08
# 4                                               0.14
#
#    Passports held: EU/EEA (not United Kingdom or Ireland) (%)  \
# 0                                               2.16
# 1                                               1.71
# 2                                               0.92
# 3                                               3.53
# 4                                               2.19
#
#    Passports held: Other (%)
# 0                       0.84
# 1                       0.95
# 2                       0.74
# 3                       0.58
# 4                       1.70

# %%
df['All usual residents'] = pd.to_numeric(df['All usual residents'].str.replace(',', ''))
df['Passports held: No passport'] = pd.to_numeric(df['Passports held: No passport'].str.replace(',', ''))
df['Passports held: United Kingdom only'] = pd.to_numeric(df['Passports held: United Kingdom only'].str.replace(',', ''))
df['Passports held: Ireland only'] = pd.to_numeric(df['Passports held: Ireland only'].str.replace(',', ''))
df['Passports held: United Kingdom and Ireland only'] = pd.to_numeric(df['Passports held: United Kingdom and Ireland only'].str.replace(',', ''))
df['Passports held: United Kingdom and other (not Ireland)'] = pd.to_numeric(df['Passports held: United Kingdom and other (not Ireland)'].str.replace(',', ''))
df['Passports held: Ireland and other (not United Kingdom)'] = pd.to_numeric(df['Passports held: Ireland and other (not United Kingdom)'].str.replace(',', ''))
df['Passports held: EU/EEA (not United Kingdom or Ireland)'] = pd.to_numeric(df['Passports held: EU/EEA (not United Kingdom or Ireland)'].str.replace(',', ''))
df['Passports held: Other'] = pd.to_numeric(df['Passports held: Other'].str.replace(',', ''))


df.head()
# Out:
#                                 LGD2014  All usual residents  Unnamed: 2  \
# 0                      Northern Ireland              1810863         NaN
# 1               Antrim and Newtownabbey               138567         NaN
# 2                   Ards and North Down               156672         NaN
# 3  Armagh City, Banbridge and Craigavon               199693         NaN
# 4                               Belfast               333871         NaN
#
#    Passports held: No passport  Passports held: United Kingdom only  \
# 0                       341428                              1035451
# 1                        21744                                96539
# 2                        22496                               120061
# 3                        38671                               113450
# 4                        53584                               186552
#
#    Passports held: Ireland only  \
# 0                        342887
# 1                         14018
# 2                          7758
# 3                         35740
# 4                         72428
#
#    Passports held: United Kingdom and Ireland only  \
# 0                                            30276
# 1                                             2098
# 2                                             3031
# 3                                             3043
# 4                                             6794
#
#    Passports held: United Kingdom and other (not Ireland)  \
# 0                                               4291
# 1                                                355
# 2                                                593
# 3                                                406
# 4                                               1040
#
#    Passports held: Ireland and other (not United Kingdom)  \
# 0                                               2282
# 1                                                128
# 2                                                118
# 3                                                169
# 4                                                484
#
#    Passports held: EU/EEA (not United Kingdom or Ireland)  \
# 0                                              39103
# 1                                               2371
# 2                                               1448
# 3                                               7050
# 4                                               7302
#
#    Passports held: Other  Passports held: No passport (%)  \
# 0                  15145                            18.85
# 1                   1314                            15.69
# 2                   1167                            14.36
# 3                   1164                            19.37
# 4                   5687                            16.05
#
#    Passports held: United Kingdom only (%)  Passports held: Ireland only (%)  \
# 0                                    57.18                             18.94
# 1                                    69.67                             10.12
# 2                                    76.63                              4.95
# 3                                    56.81                             17.90
# 4                                    55.88                             21.69
#
#    Passports held: United Kingdom and Ireland only (%)  \
# 0                                               1.67
# 1                                               1.51
# 2                                               1.93
# 3                                               1.52
# 4                                               2.03
#
#    Passports held: United Kingdom and other (not Ireland) (%)  \
# 0                                               0.24
# 1                                               0.26
# 2                                               0.38
# 3                                               0.20
# 4                                               0.31
#
#    Passports held: Ireland and other (not United Kingdom) (%)  \
# 0                                               0.13
# 1                                               0.09
# 2                                               0.08
# 3                                               0.08
# 4                                               0.14
#
#    Passports held: EU/EEA (not United Kingdom or Ireland) (%)  \
# 0                                               2.16
# 1                                               1.71
# 2                                               0.92
# 3                                               3.53
# 4                                               2.19
#
#    Passports held: Other (%)
# 0                       0.84
# 1                       0.95
# 2                       0.74
# 3                       0.58
# 4                       1.70

# %%
df.head()
# Out:
#                                 LGD2014  All usual residents  Unnamed: 2  \
# 0                      Northern Ireland              1810863         NaN
# 1               Antrim and Newtownabbey               138567         NaN
# 2                   Ards and North Down               156672         NaN
# 3  Armagh City, Banbridge and Craigavon               199693         NaN
# 4                               Belfast               333871         NaN
#
#    Passports held: No passport  Passports held: United Kingdom only  \
# 0                       341428                              1035451
# 1                        21744                                96539
# 2                        22496                               120061
# 3                        38671                               113450
# 4                        53584                               186552
#
#    Passports held: Ireland only  \
# 0                        342887
# 1                         14018
# 2                          7758
# 3                         35740
# 4                         72428
#
#    Passports held: United Kingdom and Ireland only  \
# 0                                            30276
# 1                                             2098
# 2                                             3031
# 3                                             3043
# 4                                             6794
#
#    Passports held: United Kingdom and other (not Ireland)  \
# 0                                               4291
# 1                                                355
# 2                                                593
# 3                                                406
# 4                                               1040
#
#    Passports held: Ireland and other (not United Kingdom)  \
# 0                                               2282
# 1                                                128
# 2                                                118
# 3                                                169
# 4                                                484
#
#    Passports held: EU/EEA (not United Kingdom or Ireland)  \
# 0                                              39103
# 1                                               2371
# 2                                               1448
# 3                                               7050
# 4                                               7302
#
#    Passports held: Other  Passports held: No passport (%)  \
# 0                  15145                            18.85
# 1                   1314                            15.69
# 2                   1167                            14.36
# 3                   1164                            19.37
# 4                   5687                            16.05
#
#    Passports held: United Kingdom only (%)  Passports held: Ireland only (%)  \
# 0                                    57.18                             18.94
# 1                                    69.67                             10.12
# 2                                    76.63                              4.95
# 3                                    56.81                             17.90
# 4                                    55.88                             21.69
#
#    Passports held: United Kingdom and Ireland only (%)  \
# 0                                               1.67
# 1                                               1.51
# 2                                               1.93
# 3                                               1.52
# 4                                               2.03
#
#    Passports held: United Kingdom and other (not Ireland) (%)  \
# 0                                               0.24
# 1                                               0.26
# 2                                               0.38
# 3                                               0.20
# 4                                               0.31
#
#    Passports held: Ireland and other (not United Kingdom) (%)  \
# 0                                               0.13
# 1                                               0.09
# 2                                               0.08
# 3                                               0.08
# 4                                               0.14
#
#    Passports held: EU/EEA (not United Kingdom or Ireland) (%)  \
# 0                                               2.16
# 1                                               1.71
# 2                                               0.92
# 3                                               3.53
# 4                                               2.19
#
#    Passports held: Other (%)
# 0                       0.84
# 1                       0.95
# 2                       0.74
# 3                       0.58
# 4                       1.70

# %%
df
# Out:
#                                  LGD2014  All usual residents  Unnamed: 2  \
# 0                       Northern Ireland              1810863         NaN
# 1                Antrim and Newtownabbey               138567         NaN
# 2                    Ards and North Down               156672         NaN
# 3   Armagh City, Banbridge and Craigavon               199693         NaN
# 4                                Belfast               333871         NaN
# 5               Causeway Coast and Glens               140877         NaN
# 6                Derry City and Strabane               147720         NaN
# 7                    Fermanagh and Omagh               113161         NaN
# 8                Lisburn and Castlereagh               134841         NaN
# 9                    Mid and East Antrim               135338         NaN
# 10                            Mid Ulster               138590         NaN
# 11                Newry, Mourne and Down               171533         NaN
#
#     Passports held: No passport  Passports held: United Kingdom only  \
# 0                        341428                              1035451
# 1                         21744                                96539
# 2                         22496                               120061
# 3                         38671                               113450
# 4                         53584                               186552
# 5                         34111                                83209
# 6                         31256                                55086
# 7                         27950                                50036
# 8                         18628                                97014
# 9                         26575                                96057
# 10                        33351                                61323
# 11                        33062                                76124
#
#     Passports held: Ireland only  \
# 0                         342887
# 1                          14018
# 2                           7758
# 3                          35740
# 4                          72428
# 5                          18680
# 6                          56642
# 7                          29937
# 8                          12893
# 9                           7545
# 10                         33916
# 11                         53330
#
#     Passports held: United Kingdom and Ireland only  \
# 0                                             30276
# 1                                              2098
# 2                                              3031
# 3                                              3043
# 4                                              6794
# 5                                              1884
# 6                                              2021
# 7                                              1576
# 8                                              2618
# 9                                              1758
# 10                                             2168
# 11                                             3285
#
#     Passports held: United Kingdom and other (not Ireland)  \
# 0                                                4291
# 1                                                 355
# 2                                                 593
# 3                                                 406
# 4                                                1040
# 5                                                 254
# 6                                                 177
# 7                                                 190
# 8                                                 449
# 9                                                 367
# 10                                                184
# 11                                                276
#
#     Passports held: Ireland and other (not United Kingdom)  \
# 0                                                2282
# 1                                                 128
# 2                                                 118
# 3                                                 169
# 4                                                 484
# 5                                                 120
# 6                                                 231
# 7                                                 241
# 8                                                 144
# 9                                                  62
# 10                                                231
# 11                                                354
#
#     Passports held: EU/EEA (not United Kingdom or Ireland)  \
# 0                                               39103
# 1                                                2371
# 2                                                1448
# 3                                                7050
# 4                                                7302
# 5                                                1828
# 6                                                1327
# 7                                                2698
# 8                                                1828
# 9                                                2304
# 10                                               6834
# 11                                               4113
#
#     Passports held: Other  Passports held: No passport (%)  \
# 0                   15145                            18.85
# 1                    1314                            15.69
# 2                    1167                            14.36
# 3                    1164                            19.37
# 4                    5687                            16.05
# 5                     791                            24.21
# 6                     980                            21.16
# 7                     533                            24.70
# 8                    1267                            13.81
# 9                     670                            19.64
# 10                    583                            24.06
# 11                    989                            19.27
#
#     Passports held: United Kingdom only (%)  Passports held: Ireland only (%)  \
# 0                                     57.18                             18.94
# 1                                     69.67                             10.12
# 2                                     76.63                              4.95
# 3                                     56.81                             17.90
# 4                                     55.88                             21.69
# 5                                     59.06                             13.26
# 6                                     37.29                             38.34
# 7                                     44.22                             26.46
# 8                                     71.95                              9.56
# 9                                     70.98                              5.57
# 10                                    44.25                             24.47
# 11                                    44.38                             31.09
#
#     Passports held: United Kingdom and Ireland only (%)  \
# 0                                                1.67
# 1                                                1.51
# 2                                                1.93
# 3                                                1.52
# 4                                                2.03
# 5                                                1.34
# 6                                                1.37
# 7                                                1.39
# 8                                                1.94
# 9                                                1.30
# 10                                               1.56
# 11                                               1.92
#
#     Passports held: United Kingdom and other (not Ireland) (%)  \
# 0                                                0.24
# 1                                                0.26
# 2                                                0.38
# 3                                                0.20
# 4                                                0.31
# 5                                                0.18
# 6                                                0.12
# 7                                                0.17
# 8                                                0.33
# 9                                                0.27
# 10                                               0.13
# 11                                               0.16
#
#     Passports held: Ireland and other (not United Kingdom) (%)  \
# 0                                                0.13
# 1                                                0.09
# 2                                                0.08
# 3                                                0.08
# 4                                                0.14
# 5                                                0.09
# 6                                                0.16
# 7                                                0.21
# 8                                                0.11
# 9                                                0.05
# 10                                               0.17
# 11                                               0.21
#
#     Passports held: EU/EEA (not United Kingdom or Ireland) (%)  \
# 0                                                2.16
# 1                                                1.71
# 2                                                0.92
# 3                                                3.53
# 4                                                2.19
# 5                                                1.30
# 6                                                0.90
# 7                                                2.38
# 8                                                1.36
# 9                                                1.70
# 10                                               4.93
# 11                                               2.40
#
#     Passports held: Other (%)
# 0                        0.84
# 1                        0.95
# 2                        0.74
# 3                        0.58
# 4                        1.70
# 5                        0.56
# 6                        0.66
# 7                        0.47
# 8                        0.94
# 9                        0.50
# 10                       0.42
# 11                       0.58
